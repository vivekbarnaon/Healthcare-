# %%
import pandas as pd

# %%
dia = pd.read_csv('diabetes_prediction_dataset.csv')

# %%
dia
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
dia.isnull().mean()*100
# Out:
# gender                 0.0
# age                    0.0
# hypertension           0.0
# heart_disease          0.0
# smoking_history        0.0
# bmi                    0.0
# HbA1c_level            0.0
# blood_glucose_level    0.0
# diabetes               0.0
# dtype: float64

# %%
dia['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
dia
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    dia.drop(columns=['diabetes']),
    dia['diabetes'],
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
transformer = ColumnTransformer(
    transformers=[
        ('tnf1', OrdinalEncoder(categories=[['never', 'former', 'current', 'not current', 'ever', 'No Info']]), ['smoking_history']),
        ('tnf2', OneHotEncoder(), ['gender'])
    ],
    remainder='passthrough'
)

# %%
t = transformer.fit_transform(X_train)
t_ = transformer.transform(X_test)

# %%
t_
# Out:
# array([[  5.  ,   1.  ,   0.  , ...,  20.82,   5.8 , 126.  ],
#        [  5.  ,   1.  ,   0.  , ...,  21.  ,   5.  , 145.  ],
#        [  1.  ,   0.  ,   1.  , ...,  25.32,   3.5 , 200.  ],
#        ...,
#        [  0.  ,   1.  ,   0.  , ...,  26.51,   4.8 , 100.  ],
#        [  5.  ,   0.  ,   1.  , ...,  27.32,   6.6 , 100.  ],
#        [  0.  ,   1.  ,   0.  , ...,  23.86,   5.8 , 145.  ]])

# %%
X_train
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 75220    Male  73.0             0              0          former  24.77
# 48955    Male  80.0             0              0           never  24.60
# 44966  Female  38.0             0              0            ever  24.33
# 13568  Female  26.0             0              0     not current  18.87
# 92727  Female  61.0             1              0         current  22.11
# ...       ...   ...           ...            ...             ...    ...
# 6265     Male  49.0             0              0           never  32.98
# 54886  Female  15.0             0              0           never  28.10
# 76820    Male  42.0             0              0           never  26.14
# 860    Female  37.0             0              0           never  24.96
# 15795  Female  23.0             0              0           never  27.99
#
#        HbA1c_level  blood_glucose_level
# 75220          3.5                   80
# ...

# %%
encoded_columns = ['smoking_history_encoded']  # 1 column for smoking_history
gender_columns = ['gender_female', 'gender_male']  # 2 columns for gender
remaining_columns = [col for col in X_train.columns if col not in ['smoking_history', 'gender']]
new_column_names = encoded_columns + gender_columns + remaining_columns

# %%
transformed_columns = transformer.get_feature_names_out(input_features=X_train.columns)

# %%
new_column_names
# Out:
# ['smoking_history_encoded',
#  'gender_female',
#  'gender_male',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'bmi',
#  'HbA1c_level',
#  'blood_glucose_level']

# %%
X_train_transformed = pd.DataFrame(t, columns=transformed_columns, index=X_train.index)
X_test_transformed = pd.DataFrame(t_, columns=transformed_columns, index=X_test.index)

# %%
X_train_transformed
# Out:
#        tnf1__smoking_history  tnf2__gender_Female  tnf2__gender_Male  \
# 75220                    1.0                  0.0                1.0
# 48955                    0.0                  0.0                1.0
# 44966                    4.0                  1.0                0.0
# 13568                    3.0                  1.0                0.0
# 92727                    2.0                  1.0                0.0
# ...                      ...                  ...                ...
# 6265                     0.0                  0.0                1.0
# 54886                    0.0                  1.0                0.0
# 76820                    0.0                  0.0                1.0
# 860                      0.0                  1.0                0.0
# 15795                    0.0                  1.0                0.0
#
#        tnf2__gender_Other  remainder__age  remainder__hypertension  \
# 75220                 0.0            73.0                      0.0
# ...

# %%
X_train_transformed.columns
# Out:
# Index(['tnf1__smoking_history', 'tnf2__gender_Female', 'tnf2__gender_Male',
#        'tnf2__gender_Other', 'remainder__age', 'remainder__hypertension',
#        'remainder__heart_disease', 'remainder__bmi', 'remainder__HbA1c_level',
#        'remainder__blood_glucose_level'],
#       dtype='object')

# %%
new_column_names = [col.split('__')[-1] for col in X_train_transformed.columns]

X_train_transformed.columns = new_column_names
X_test_transformed.columns = new_column_names

# %%
X_train_transformed
# Out:
#        smoking_history  gender_Female  gender_Male  gender_Other   age  \
# 75220              1.0            0.0          1.0           0.0  73.0
# 48955              0.0            0.0          1.0           0.0  80.0
# 44966              4.0            1.0          0.0           0.0  38.0
# 13568              3.0            1.0          0.0           0.0  26.0
# 92727              2.0            1.0          0.0           0.0  61.0
# ...                ...            ...          ...           ...   ...
# 6265               0.0            0.0          1.0           0.0  49.0
# 54886              0.0            1.0          0.0           0.0  15.0
# 76820              0.0            0.0          1.0           0.0  42.0
# 860                0.0            1.0          0.0           0.0  37.0
# 15795              0.0            1.0          0.0           0.0  23.0
#
#        hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

model = LogisticRegression(max_iter=1000)
model.fit(X_train_transformed, y_train)

y_pred = model.predict(X_test_transformed)

accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X_train_transformed, y_train, cv=5)
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Cross-Validation Score: {cv_scores.mean()}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [0.9593125 0.960875  0.961375  0.9604375 0.9609375]
# Mean Cross-Validation Score: 0.9605874999999999

# %%
from sklearn.metrics import accuracy_score

# Train the model
model = LogisticRegression(max_iter=1000)  # Example model, you can replace it with any model
model.fit(X_train_transformed, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_transformed)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9591

# %%
from sklearn.metrics import classification_report

# Make predictions on the test set
y_pred = model.predict(X_test_transformed)

# Generate the classification report
report = classification_report(y_test, y_pred)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18292
#            1       0.87      0.62      0.72      1708
#
#     accuracy                           0.96     20000
#    macro avg       0.92      0.80      0.85     20000
# weighted avg       0.96      0.96      0.96     20000

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train_transformed, y_train)

# Predict on the test data
y_pred = rf_model.predict(X_test_transformed)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.97015
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     18292
#            1       0.94      0.69      0.80      1708
#
#     accuracy                           0.97     20000
#    macro avg       0.96      0.84      0.89     20000
# weighted avg       0.97      0.97      0.97     20000
#
#
# Confusion Matrix:
# [[18223    69]
#  [  528  1180]]

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize the XGBoost model
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42, use_label_encoder=False)

# Train the model
xgb_model.fit(X_train_transformed, y_train)

# Predict on test data
y_pred = xgb_model.predict(X_test_transformed)

# Evaluate performance
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:27:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.9725
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     18292
#            1       0.98      0.69      0.81      1708
#
#     accuracy                           0.97     20000
#    macro avg       0.98      0.84      0.90     20000
# weighted avg       0.97      0.97      0.97     20000

# %%
from lightgbm import LGBMClassifier

# Initialize the LightGBM model
lgbm_model = LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

# Train the model
lgbm_model.fit(X_train_transformed, y_train)

# Predict on test data
y_pred = lgbm_model.predict(X_test_transformed)

# Evaluate performance
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [LightGBM] [Info] Number of positive: 6792, number of negative: 73208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006882 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 410
# [LightGBM] [Info] Number of data points in the train set: 80000, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.084900 -> initscore=-2.377559
# [LightGBM] [Info] Start training from score -2.377559
# Accuracy: 0.9725
# Classification Report:
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Initialize the Logistic Regression model
log_reg_model = LogisticRegression(random_state=42, max_iter=1000)

# Train the model
log_reg_model.fit(X_train_transformed, y_train)

# Predict on the test set
y_pred = log_reg_model.predict(X_test_transformed)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9591
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18292
#            1       0.87      0.62      0.72      1708
#
#     accuracy                           0.96     20000
#    macro avg       0.92      0.80      0.85     20000
# weighted avg       0.96      0.96      0.96     20000

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report

# Initialize the LightGBM model with class imbalance handling
model = LGBMClassifier(is_unbalance=True)

# Train the model on the transformed data
model.fit(X_train_transformed, y_train)

# Predict on the test set
y_pred = model.predict(X_test_transformed)

# Evaluate the model
print("Accuracy:", model.score(X_test_transformed, y_test))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 6792, number of negative: 73208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 410
# [LightGBM] [Info] Number of data points in the train set: 80000, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.084900 -> initscore=-2.377559
# [LightGBM] [Info] Start training from score -2.377559
# Accuracy: 0.9159
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95     18292
#            1       0.50      0.90      0.65      1708
#
#     accuracy                           0.92     20000
#    macro avg       0.75      0.91      0.80     20000
# weighted avg       0.95      0.92      0.93     20000

# %%
from lightgbm import LGBMClassifier

# Define the model with class_weight
model = LGBMClassifier(class_weight={0: 1, 1: 10}, is_unbalance=True)

# Train and evaluate the model
model.fit(X_train_transformed, y_train)
y_pred = model.predict(X_test_transformed)

# Evaluate the model
print("Accuracy:", model.score(X_test_transformed, y_test))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 6792, number of negative: 73208
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 410
# [LightGBM] [Info] Number of data points in the train set: 80000, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.481265 -> initscore=-0.074974
# [LightGBM] [Info] Start training from score -0.074974
# Accuracy: 0.8214
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     18292
#            1       0.32      0.98      0.48      1708
#
#     accuracy                           0.82     20000
#    macro avg       0.66      0.89      0.69     20000
# weighted avg       0.94      0.82      0.86     20000

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_transformed, y_train)

# Train the model
model = LGBMClassifier()
model.fit(X_train_smote, y_train_smote)

# Get predicted probabilities
y_prob = model.predict_proba(X_test_transformed)[:, 1]

# Set a new threshold (e.g., 0.4 instead of 0.3)
y_pred_new = (y_prob >= 0.4).astype(int)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred_new))
print("Classification Report:")
print(classification_report(y_test, y_pred_new))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 73208, number of negative: 73208
# ...
